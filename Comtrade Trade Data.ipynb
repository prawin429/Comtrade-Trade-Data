# %%
import requests
import json
import pandas as pd
CC = 252321
R = 842
url='https://comtrade.un.org/api/get?r='+str(R)+'&px=HS&ps=2020%2C2019%2C2018%2C2017%2C2016&rg=1&p=0&cc='+str(CC)+'&type=c&freq=a'
res = requests.get(url).json()

# %%
res
# Out:
# {'validation': {'status': {'name': 'Ok',
#    'value': 0,
#    'category': 0,
#    'description': '',
#    'helpUrl': 'For more reference visit http://comtrade.un.org/data/dev/portal/'},
#   'message': None,
#   'count': {'value': 5,
#    'started': '2022-04-02T13:14:36.7368202+02:00',
#    'finished': '2022-04-02T13:14:37.2224005+02:00',
#    'durationSeconds': 0.48558029999999996},
#   'datasetTimer': {'started': '2022-04-02T13:14:36.7368202+02:00',
#    'finished': '2022-04-02T13:14:38.2862747+02:00',
#    'durationSeconds': 1.5494545}},
#  'dataset': [{'pfCode': 'H5',
#    'yr': 2017,
#    'period': 2017,
#    'periodDesc': '2017',
#    'aggrLevel': 6,
#    'IsLeaf': 1,
#    'rgCode': 1,
#    'rgDesc': 'Import',
#    'rtCode': 842,
#    'rtTitle': 'USA',
#    'rt3ISO': 'USA',
#    'ptCode': 0,
#    'ptTitle': 'World',
#    'pt3ISO': 'WLD',
#    'ptCode2': None,
#    'ptTitle2': '',
#    'pt3ISO2': '',
#    'cstCode': '',
#    'cstDesc': '',
#    'motCode': '',
# ...

# %%
json_object = json.dumps(res['dataset'], indent = 4)
  
# Writing to sample.json
with open("sample.json", "w") as outfile:
    outfile.write(json_object)

# %%
df_json = pd.read_json('sample.json')
df_json.to_excel('DATAFILE.xlsx')

# %%
praveen=pd.read_excel('DATAFILE.xlsx', index_col=0)

# %%
praveen
# Out:
#   pfCode    yr  period  periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H5  2017    2017        2017          6       1       1  Import     842
# 1     H5  2018    2018        2018          6       1       1  Import     842
# 2     H5  2019    2019        2019          6       1       1  Import     842
# 3     H5  2020    2020        2020          6       1       1  Import     842
# 4     H4  2016    2016        2016          6       1       1  Import     842
#
#   rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity   NetWeight  \
# 0     USA  ...       NaN        NaN    1277982000         NaN  1277982000
# 1     USA  ...       NaN        NaN    1410560000         NaN  1410560000
# 2     USA  ...       NaN        NaN    1411709000         NaN  1411709000
# 3     USA  ...       NaN        NaN    1146336000         NaN  1146336000
# 4     USA  ...       NaN        NaN    1274782000         NaN  1274782000
#
# ...

# %%
praveen.columns
# Out:
# Index(['pfCode', 'yr', 'period', 'periodDesc', 'aggrLevel', 'IsLeaf', 'rgCode',
#        'rgDesc', 'rtCode', 'rtTitle', 'rt3ISO', 'ptCode', 'ptTitle', 'pt3ISO',
#        'ptCode2', 'ptTitle2', 'pt3ISO2', 'cstCode', 'cstDesc', 'motCode',
#        'motDesc', 'cmdCode', 'cmdDescE', 'qtCode', 'qtDesc', 'qtAltCode',
#        'qtAltDesc', 'TradeQuantity', 'AltQuantity', 'NetWeight', 'GrossWeight',
#        'TradeValue', 'CIFValue', 'FOBValue', 'estCode'],
#       dtype='object')

# %%
Tradequan=praveen[['yr','rgDesc','ptTitle','NetWeight','cmdCode','qtDesc']]

# %%
Tradequan
# Out:
#      yr  rgDesc ptTitle   NetWeight  cmdCode               qtDesc
# 0  2017  Import   World  1277982000   252321  Weight in kilograms
# 1  2018  Import   World  1410560000   252321  Weight in kilograms
# 2  2019  Import   World  1411709000   252321  Weight in kilograms
# 3  2020  Import   World  1146336000   252321  Weight in kilograms
# 4  2016  Import   World  1274782000   252321  Weight in kilograms

# %%
value=praveen[['yr','rgDesc','TradeValue','ptTitle','cmdCode']]

# %%
value
# Out:
#      yr  rgDesc  TradeValue ptTitle  cmdCode
# 0  2017  Import   174024325   World   252321
# 1  2018  Import   190127416   World   252321
# 2  2019  Import   190798454   World   252321
# 3  2020  Import   171212775   World   252321
# 4  2016  Import   166960521   World   252321

# %%
url1='https://comtrade.un.org/api/get?r='+str(R)+'&px=HS&ps=2020%2C2019%2C2018%2C2017%2C2016&rg=2&p=0&cc='+str(CC)+'&type=c&freq=a'
res1 = requests.get(url).json()

# %%
res1
# Out:
# {'validation': {'status': {'name': 'Ok',
#    'value': 0,
#    'category': 0,
#    'description': '',
#    'helpUrl': 'For more reference visit http://comtrade.un.org/data/dev/portal/'},
#   'message': None,
#   'count': {'value': 5,
#    'started': '2022-04-02T13:14:36.7368202+02:00',
#    'finished': '2022-04-02T13:14:37.2224005+02:00',
#    'durationSeconds': 0.48558029999999996},
#   'datasetTimer': {'started': '2022-04-02T13:14:36.7368202+02:00',
#    'finished': '2022-04-02T13:14:38.2862747+02:00',
#    'durationSeconds': 1.5494545}},
#  'dataset': [{'pfCode': 'H5',
#    'yr': 2017,
#    'period': 2017,
#    'periodDesc': '2017',
#    'aggrLevel': 6,
#    'IsLeaf': 1,
#    'rgCode': 1,
#    'rgDesc': 'Import',
#    'rtCode': 842,
#    'rtTitle': 'USA',
#    'rt3ISO': 'USA',
#    'ptCode': 0,
#    'ptTitle': 'World',
#    'pt3ISO': 'WLD',
#    'ptCode2': None,
#    'ptTitle2': '',
#    'pt3ISO2': '',
#    'cstCode': '',
#    'cstDesc': '',
#    'motCode': '',
# ...

# %%
json_object1 = json.dumps(res1['dataset'], indent = 4)
  
# Writing to sample.json
with open("sample1.json", "w") as outfile:
    outfile.write(json_object1)

# %%
df_json1 = pd.read_json('sample1.json')
df_json1.to_excel('DATAFILE1.xlsx')

# %%
praveen1=pd.read_excel('DATAFILE1.xlsx', index_col=0)

# %%
Tradequan1=praveen1[['yr','rgDesc','ptTitle','NetWeight','cmdCode','qtDesc']]

# %%
value1=praveen1[['yr','rgDesc','TradeValue','ptTitle','cmdCode']]

# %%
import requests
import json
import pandas as pd
CC = 252321
R = 842
url2='https://comtrade.un.org/api/get?r='+str(R)+'&px=HS&ps=2015%2C2021&rg=1&p=0&cc='+str(CC)+'&type=c&freq=a'
res2 = requests.get(url2).json()
json_object2 = json.dumps(res2['dataset'], indent = 4)
  
# Writing to sample.json
with open("sample2.json", "w") as outfile:
    outfile.write(json_object2)

# %%
df_json2 = pd.read_json('sample2.json')
df_json2.to_excel('DATAFILE2.xlsx')
praveen2=pd.read_excel('DATAFILE2.xlsx', index_col=0)

# %%
praveen2
# Out:
#   pfCode    yr  period  periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H5  2021    2021        2021          6       1       1  Import     842
# 1     H4  2015    2015        2015          6       1       1  Import     842
#
#   rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity   NetWeight  \
# 0     USA  ...       NaN        NaN    1805909000         NaN  1805909000
# 1     USA  ...       NaN        NaN    1135679992         NaN  1135679992
#
#    GrossWeight  TradeValue  CIFValue  FOBValue  estCode
# 0          NaN   194474719       NaN       NaN        0
# 1          NaN   152828683       NaN       NaN        0
#
# [2 rows x 35 columns]

# %%
Tradequan2=praveen2[['yr','rgDesc','ptTitle','NetWeight','cmdCode','qtDesc']]

# %%
value2=praveen2[['yr','rgDesc','TradeValue','ptTitle','cmdCode']]

# %%
import requests
import json
import pandas as pd
CC = 252321
R = 842
url3='https://comtrade.un.org/api/get?r='+str(R)+'&px=HS&ps=2015%2C2021&rg=2&p=0&cc='+str(CC)+'&type=c&freq=a'
res3 = requests.get(url3).json()
json_object3 = json.dumps(res3['dataset'], indent = 4)
  
# Writing to sample.json
with open("sample3.json", "w") as outfile:
    outfile.write(json_object3)

# %%
df_json3 = pd.read_json('sample3.json')
df_json3.to_excel('DATAFILE3.xlsx')
praveen3=pd.read_excel('DATAFILE3.xlsx', index_col=0)

# %%
praveen3
# Out:
#   pfCode    yr  period  periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H5  2021    2021        2021          6       1       2  Export     842
# 1     H4  2015    2015        2015          6       1       2  Export     842
#
#   rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity  NetWeight  \
# 0     USA  ...       NaN        NaN      56897000         NaN   56897000
# 1     USA  ...       NaN        NaN     194777000         NaN  194777000
#
#    GrossWeight  TradeValue  CIFValue  FOBValue  estCode
# 0          NaN    12264462       NaN       NaN        0
# 1          NaN    39956893       NaN       NaN        0
#
# [2 rows x 35 columns]

# %%
Tradequan3=praveen3[['yr','rgDesc','ptTitle','NetWeight','cmdCode','qtDesc']]

# %%
value3=praveen3[['yr','rgDesc','TradeValue','ptTitle','cmdCode']]

# %%
writer = pd.ExcelWriter('Ugadi.xlsx', engine='xlsxwriter')

# %%
Tradequan.to_excel(writer, sheet_name='Totalimpquan')
value.to_excel(writer, sheet_name='Totalimpval')
Tradequan1.to_excel(writer, sheet_name='Totalexpquan')
value1.to_excel(writer, sheet_name='Totalexpval')
Tradequan3.to_excel(writer, sheet_name='Imp20152021')
value3.to_excel(writer, sheet_name='Exp20152021')

# %%
writer.save()
